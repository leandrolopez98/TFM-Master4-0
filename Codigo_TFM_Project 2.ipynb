# %%
import os
# os.environ["CUDA_LAUNCH_BLOCKING"] = '1'
import cv2
import time
import torch
import copy
import random

import torchvision
import numpy as np
import pandas as pd
from PIL import Image
from torch import nn
from sklearn import metrics
import matplotlib.pyplot as plt

import albumentations as A
from torchvision import models
from torchvision import datasets
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from albumentations.pytorch.transforms import ToTensorV2

torch.cuda.empty_cache()
random.seed(42)
torch.manual_seed(42)
torch.cuda.manual_seed_all(42)
np.random.seed(42)
# torch.backends.cudnn.benchmark = False
# torch.backends.cudnn.deterministic = True
# os.environ["CUBLAS_WORKSPACE_CONFIG"] = ':16:8'
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 17
#      14 from sklearn import metrics
#      15 import matplotlib.pyplot as plt
# ---> 17 import albumentations as A
#      18 from torchvision import models
#      19 from torchvision import datasets
#
# ModuleNotFoundError: No module named 'albumentations'

# %%
class_dict = {'detergent-color': 0,
 'detergent-white': 1,
 'detergent-transparent': 2,
 'detergent-box': 3,
 'juice-cardboard': 4,
 'milk-cardboard': 5,
 'cans': 6,
 'canister': 7,
 'bottle-blue': 8,
 'bottle-green-full': 9,
 'bottle-dark': 10,
 'bottle-oil-full': 11,
 'bottle-transp': 12,
 'bottle-multicolor': 13,
 'bottle-oil': 14,
 'bottle-multicolorv-full': 15,
 'bottle-milk': 16,
 'bottle-milk-full': 17,
 'bottle-green': 18,
 'bottle-blue-full': 19,
 'glass-transp': 20,
 'bottle-blue5l': 21,
 'bottle-transp-full': 22,
 'bottle-yogurt': 23,
 'bottle-blue5l-full': 24,
 'glass-green': 25,
 'glass-dark': 26,
 'bottle-dark-full': 27}

# %%
def path_n_dict(root,train_ratio = None):
    path_im = []
    label_im = [] 
    for k in os.listdir(root):
        big_class = os.path.join(root,k)
        for i in os.listdir(big_class):
            per_class_path = os.path.join(big_class,i)
            for j in os.listdir(per_class_path):
                path_im.append(os.path.join(per_class_path,j)) 
                label_im.append(class_dict[i])
    if train_ratio :
        return train_test_split(path_im,label_im,train_size=train_ratio,random_state=42)
    return (path_im,label_im)

# %%
class MyDataset(Dataset):
    def __init__(self,path,label,transforms = None):
        self.path_image = path
        self.labels = label
        self.transforms = transforms
    def __len__(self):
        return len(self.labels)
    def __getitem__(self,idx):
        image = cv2.imread(self.path_image[idx])
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        label = self.labels[idx]
        if self.transforms:
            image = self.transforms(image = image)
        return image,label

# %%
data_transforms = {
    'train': A.Compose(
    [   
        A.LongestMaxSize(max_size=456,interpolation = 2),
        A.PadIfNeeded(min_height=456, min_width=456),
        A.ShiftScaleRotate(shift_limit=0.1, scale_limit=0.1, rotate_limit=90, p=0.8),
        A.RGBShift(r_shift_limit=15, g_shift_limit=15, b_shift_limit=15, p=0.5),
        A.RandomBrightnessContrast(brightness_limit=0.1, contrast_limit=0.1, p=0.5),
        A.HorizontalFlip(),
        A.VerticalFlip(),
        A.CoarseDropout(max_holes=40, max_height=32, max_width=32, always_apply=True),
        A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
        ToTensorV2(),
    ]
),
    'val': A.Compose(
    [   
        A.LongestMaxSize(max_size=456,interpolation = 2),
        A.PadIfNeeded(min_height=456, min_width=456),
#       A.CenterCrop(380,380,always_apply=True),
        A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
        ToTensorV2(),
    ])
}
g = torch.Generator()
g.manual_seed(42)

train_path,val_path,train_label,val_label = path_n_dict('/kaggle/input/warp-waste-recycling-plant-dataset/Warp-C/train_crops',train_ratio = 0.8)
test_path,test_label = path_n_dict('/kaggle/input/warp-waste-recycling-plant-dataset/Warp-C/test_crops')

train_dataset = MyDataset(train_path,train_label,transforms = data_transforms["train"])
val_dataset = MyDataset(val_path,val_label,transforms = data_transforms["val"])
test_dataset = MyDataset(test_path,test_label,transforms = data_transforms["val"] )


train_loader = DataLoader(train_dataset,batch_size = 16,shuffle=True, num_workers=2,generator=g,drop_last = True)
val_loader = DataLoader(val_dataset,batch_size = 16,shuffle=False, num_workers=2,generator=g)
test_loader = DataLoader(test_dataset,batch_size = 16,shuffle=False, num_workers=2,generator=g)

# %%
def imshow(inp, title=None):
    """Display image for Tensor."""
    inp = inp.numpy().transpose((1, 2, 0))
    plt.figure(figsize=(16, 6))
    plt.imshow(inp)
    if title is not None:
        plt.title(title)
    plt.pause(0.001)

key_list = list(class_dict.keys())
inputs,classes = next(iter(train_loader))
out = torchvision.utils.make_grid(inputs['image'])

imshow(out, title=[key_list[x.item()] for x in classes])

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda', index=0)

# %%
base_model = models.efficientnet_b5(weights='IMAGENET1K_V1')
# for param in base_model.parameters():
#      param.requires_grad = False
base_model.classifier = nn.Sequential(*base_model.classifier,
                                      nn.BatchNorm1d(1000),
                                      nn.Linear(1000,256),
                                      nn.ReLU(),
                                      nn.Dropout(0.4),
                                      nn.Linear(256,28))
# base_model.classifier = nn.Sequential(*base_model.classifier,
#                                       nn.BatchNorm1d(1000),
#                                       nn.Linear(1000,512),
#                                       nn.ReLU(),
#                                       nn.Linear(512,256),
#                                       nn.ReLU(),
#                                       nn.Dropout(0.4),
#                                       nn.Linear(256,28))
base_model = nn.DataParallel(base_model)
base_model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(base_model.parameters(),lr = 0.001)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer,'max',patience = 2,factor = 0.25)
# Out:
# Downloading: "https://download.pytorch.org/models/efficientnet_b5_lukemelas-b6417697.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b5_lukemelas-b6417697.pth
# 100%|██████████| 117M/117M [00:00<00:00, 237MB/s]

# %% [markdown]
# base_model = models.convnext_tiny(weights='IMAGENET1K_V1')
# # for param in base_model.parameters():
# #      param.requires_grad = False
# # base_model = models.resnet50(weights='IMAGENET1K_V1')
# base_model.classifier = nn.Sequential(*base_model.classifier,
#                                       nn.BatchNorm1d(1000),
#                                       nn.Linear(1000,512),
#                                       nn.ReLU(),
#                                       nn.Linear(512,256),
#                                       nn.ReLU(),
#                                       nn.Dropout(0.4),
#                                       nn.Linear(256,28))
# base_model.to(device)
# criterion = nn.CrossEntropyLoss()
# optimizer = torch.optim.AdamW(base_model.parameters(),lr = 0.001)
# scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer,'max', factor=0.25, patience=2, verbose=True)

# %%
def train(model,criterion,optimizer,scheduler,epochs,resume_train = False,PATH = None):
    if resume_train:
        checkpoint = torch.load(PATH)
        model.load_state_dict(checkpoint['model_state_dict'])
        #optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    start = time.time()
    best_model_wts = copy.deepcopy(model.state_dict())
    best_epoch = None
    best_acc = 0.0
    val_loss = 100.0
    t_list_loss = []
    t_list_acc = []
    v_list_loss = []
    v_list_acc = []
    for epoch in range(epochs):
        epoch_start = time.time()
        print("Epoch: {}/{}".format(epoch+1, epochs))

        model.train()

        train_loss = 0.0
        train_acc = 0.0

        val_loss = 0.0
        val_acc = 0.0

        for inputs,labels in train_loader:
            inputs = inputs['image']
            inputs = inputs.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)
            preds = outputs.argmax(dim=1)
            loss = criterion(outputs,labels)
            loss.backward()

            optimizer.step()

            train_loss += loss.item()*inputs.size(0)
            train_acc += torch.sum(preds==labels)


        with torch.no_grad():
            model.eval()
            for inputs,labels in val_loader:
                inputs = inputs['image']
                inputs = inputs.to(device)
                labels = labels.to(device)

                outputs = model(inputs)
                preds = outputs.argmax(dim=1)

                loss = criterion(outputs,labels)

                val_loss += loss.item()*inputs.size(0)
                val_acc += torch.sum(preds==labels)

        train_loss = train_loss/len(train_dataset)
        train_acc = train_acc.double()/len(train_dataset)

        val_loss = val_loss/(len(val_dataset))
        val_acc = val_acc.double()/(len(val_dataset))

        t_list_loss.append(train_loss)
        t_list_acc.append(train_acc)
        v_list_loss.append(val_loss)
        v_list_acc.append(val_acc)

        print(f'Train Loss: {train_loss:.4f} Acc: {train_acc:.4f}')
        print(f'Val Loss: {val_loss:.4f} Acc: {val_acc:.4f} ')
        scheduler.step(val_acc)

        if ((val_acc>best_acc) or ((val_acc==best_acc) and (val_loss<best_loss))) :
            best_acc = val_acc
            best_epoch = epoch+1
            best_model_wts = copy.deepcopy(model.state_dict())
            best_loss = val_loss

    total_time = time.time() - start
    print(f'Training complete in {total_time // 60:.0f}m {total_time % 60:.0f}s')
    print(f'Best val Epoch: {best_epoch:4f}')
    print(f'Val Acc: {best_acc:4f}')
    model.load_state_dict(best_model_wts)
    return model,t_list_loss,t_list_acc,v_list_loss,v_list_acc

# %%
epochs = 40
model_trained,t_list_loss,t_list_acc,v_list_loss,v_list_acc = train(base_model,
                                                                    criterion,
                                                                    optimizer,
                                                                    scheduler,
                                                                    epochs,
                                                                    resume_train = False,
                                                                    PATH='/kaggle/input/model-loader/model_b5.pt')
torch.save({'model_state_dict': model_trained.state_dict(),
            'optimizer_state_dict': optimizer.state_dict()
           },'/kaggle/working/model_b5_1.pt')
# Out:
# Epoch: 1/40
# Train Loss: 2.5644 Acc: 0.2742
# Val Loss: 4.4655 Acc: 0.3615
# Epoch: 2/40
# Train Loss: 2.0661 Acc: 0.3848
# Val Loss: 1.9581 Acc: 0.4164
# Epoch: 3/40
# Train Loss: 1.8504 Acc: 0.4354
# Val Loss: 1.7571 Acc: 0.4623
# Epoch: 4/40
# Train Loss: 1.6995 Acc: 0.4841
# Val Loss: 1.5408 Acc: 0.5547
# Epoch: 5/40
# Train Loss: 1.6377 Acc: 0.4977
# Val Loss: 1.3966 Acc: 0.6074
# Epoch: 6/40
# Train Loss: 1.5289 Acc: 0.5313
# Val Loss: 1.2347 Acc: 0.6272
# Epoch: 7/40
# Train Loss: 1.4754 Acc: 0.5487
# Val Loss: 1.5687 Acc: 0.5524
# Epoch: 8/40
# Train Loss: 1.4144 Acc: 0.5663
# Val Loss: 1.4466 Acc: 0.5722
# Epoch: 9/40
# Train Loss: 1.3908 Acc: 0.5738
# Val Loss: 1.6546 Acc: 0.5020
# Epoch: 10/40
# Train Loss: 1.1026 Acc: 0.6529
# Val Loss: 0.8839 Acc: 0.7269
# Epoch: 11/40
# Train Loss: 0.9765 Acc: 0.6896
# Val Loss: 0.8517 Acc: 0.7507
# Epoch: 12/40
# Train Loss: 0.9017 Acc: 0.7086
# Val Loss: 0.8470 Acc: 0.7592
# Epoch: 13/40
# Train Loss: 0.8501 Acc: 0.7270
# Val Loss: 0.7902 Acc: 0.7626
# Epoch: 14/40
# Train Loss: 0.8248 Acc: 0.7352
# Val Loss: 0.8241 Acc: 0.7564
# Epoch: 15/40
# Train Loss: 0.7876 Acc: 0.7519
# Val Loss: 0.7559 Acc: 0.7756
# Epoch: 16/40
# Train Loss: 0.7809 Acc: 0.7511
# Val Loss: 0.7846 Acc: 0.7660
# Epoch: 17/40
# Train Loss: 0.7273 Acc: 0.7645
# Val Loss: 0.7650 Acc: 0.7637
# Epoch: 18/40
# Train Loss: 0.7123 Acc: 0.7736
# Val Loss: 0.7796 Acc: 0.7705
# Epoch: 19/40
# Train Loss: 0.6097 Acc: 0.8004
# Val Loss: 0.7129 Acc: 0.7881
# Epoch: 20/40
# Train Loss: 0.5772 Acc: 0.8106
# Val Loss: 0.7131 Acc: 0.7938
# Epoch: 21/40
# Train Loss: 0.5472 Acc: 0.8229
# Val Loss: 0.6931 Acc: 0.7955
# Epoch: 22/40
# Train Loss: 0.5513 Acc: 0.8196
# Val Loss: 0.6969 Acc: 0.7972
# Epoch: 23/40
# Train Loss: 0.5300 Acc: 0.8247
# Val Loss: 0.7029 Acc: 0.7983
# Epoch: 24/40
# Train Loss: 0.5089 Acc: 0.8301
# Val Loss: 0.6981 Acc: 0.8034
# Epoch: 25/40
# Train Loss: 0.4986 Acc: 0.8356
# Val Loss: 0.7064 Acc: 0.7949
# Epoch: 26/40
# Train Loss: 0.5061 Acc: 0.8335
# Val Loss: 0.6992 Acc: 0.8034
# Epoch: 27/40
# Train Loss: 0.4702 Acc: 0.8410
# Val Loss: 0.7009 Acc: 0.8011
# Epoch: 28/40
# Train Loss: 0.4607 Acc: 0.8471
# Val Loss: 0.6834 Acc: 0.8051
# Epoch: 29/40
# Train Loss: 0.4330 Acc: 0.8604
# Val Loss: 0.6898 Acc: 0.8034
# Epoch: 30/40
# Train Loss: 0.4404 Acc: 0.8528
# Val Loss: 0.7044 Acc: 0.8023
# Epoch: 31/40
# Train Loss: 0.4344 Acc: 0.8536
# Val Loss: 0.6941 Acc: 0.8045
# Epoch: 32/40
# Train Loss: 0.4251 Acc: 0.8558
# Val Loss: 0.6916 Acc: 0.8051
# Epoch: 33/40
# Train Loss: 0.4295 Acc: 0.8559
# Val Loss: 0.7080 Acc: 0.8057
# Epoch: 34/40
# Train Loss: 0.4348 Acc: 0.8543
# Val Loss: 0.7064 Acc: 0.8062
# Epoch: 35/40
# Train Loss: 0.4108 Acc: 0.8664
# Val Loss: 0.6954 Acc: 0.8023
# Epoch: 36/40
# Train Loss: 0.4317 Acc: 0.8549
# Val Loss: 0.7132 Acc: 0.8017
# Epoch: 37/40
# Train Loss: 0.4162 Acc: 0.8641
# Val Loss: 0.6911 Acc: 0.8091
# Epoch: 38/40
# Train Loss: 0.4243 Acc: 0.8596
# Val Loss: 0.6880 Acc: 0.8091
# Epoch: 39/40
# Train Loss: 0.4116 Acc: 0.8617
# Val Loss: 0.6951 Acc: 0.8045
# Epoch: 40/40
# Train Loss: 0.4142 Acc: 0.8616
# Val Loss: 0.6949 Acc: 0.8102
# Training complete in 254m 4s
# Best val Epoch: 40.000000
# Val Acc: 0.810198

# %%
def cov_2_np(the_list):
  new_list = []
  for i in the_list:
    new_list.append(i)
  return new_list
t_list_acc = cov_2_np(t_list_acc)
v_list_acc = cov_2_np(v_list_acc)

# %% [markdown]
# def visualize(metric):
#   horizontal = np.arange(1,len(metric)+1,1)
#   plt.plot(horizontal,metric)
# # t_list_loss,t_list_acc,v_list_loss,v_list_acc
# plt.figure(figsize=(9, 3))
# # plt.subplot(121)
# # visualize(t_list_loss)
# # plt.xlabel('Epochs')
# # plt.ylabel('Loss')
# plt.subplot(121)
# visualize(v_list_loss)
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# # plt.subplot(122)
# # visualize(t_list_acc)
# # plt.xlabel('Epochs')
# # plt.ylabel('Accuracy')
# # plt.suptitle('Train')
# plt.subplot(122)
# visualize(v_list_acc)
# plt.xlabel('Epochs')
# plt.ylabel('Accuracy')
# plt.suptitle('Valid')

# %%
def test(model):
    start = time.time()
    y_ = []
    y = []
    with torch.no_grad():
        model.eval()
        test_loss = 0.0
        test_acc = 0.0
        for inputs,labels in test_loader:
                inputs = inputs['image']
                inputs = inputs.to(device)
                labels = labels.to(device)

                outputs = model(inputs)
                preds = outputs.argmax(dim=1)
                y = np.concatenate((y,labels.cpu().detach().numpy()))
                y_ = np.concatenate((y_,preds.cpu().detach().numpy()))
                loss = criterion(outputs,labels)

                test_loss += loss.item()*inputs.size(0)
                test_acc += torch.sum(preds==labels)
        test_loss = test_loss/len(test_dataset)
        test_acc = test_acc.double()/len(test_dataset)
    print(f'Test Loss: {test_loss:.4f} Acc: {test_acc:.4f}')
    total_time = time.time() - start
    print(f'Testing complete in {total_time // 60:.0f}m {total_time % 60:.0f}s')
    return y,y_

# %%
true_label, predict_label = test(model_trained)
# Out:
# Test Loss: 0.6973 Acc: 0.8040
# Testing complete in 0m 27s

# %%
confusion_matrix = metrics.confusion_matrix(true_label, predict_label)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = confusion_matrix)
plt.subplots_adjust(bottom=0.2)
cm_display.plot(cmap = 'Blues')
plt.show()
